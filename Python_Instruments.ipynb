# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravindra1972/Anaytics-in-finance-using-Python/blob/main/Python_Instruments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
#Acquiring Financial Data
#1.1 Getting data from Yahoo Finance

# %%
#Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
import pandas as pd
import yfinance as yf
import numpy as np

# %%
#Download the data
df = yf.download("AAPL",
 start="2011-01-01",
 end="2023-10-31",
 progress=False)

# %%
#Inspect the data
print(f"Downloaded {len(df)} rows of data.")
df
# Out:
# Downloaded 3228 rows of data.
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-01-03   11.630000   11.795000   11.601429   11.770357    9.977492
# 2011-01-04   11.872857   11.875000   11.719643   11.831786   10.029563
# 2011-01-05   11.769643   11.940714   11.767857   11.928571   10.111607
# 2011-01-06   11.954286   11.973214   11.889286   11.918929   10.103434
# 2011-01-07   11.928214   12.012500   11.853571   12.004286   10.175791
# ...                ...         ...         ...         ...         ...
# 2023-10-24  173.050003  173.669998  171.449997  173.440002  173.211807
# 2023-10-25  171.880005  173.059998  170.649994  171.100006  170.874893
# 2023-10-26  170.369995  171.380005  165.669998  166.889999  166.670425
# 2023-10-27  166.910004  168.960007  166.830002  168.220001  167.998672
# 2023-10-30  169.020004  171.169998  168.869995  170.289993  170.065933
#
#                Volume
# Date
# 2011-01-03  445138400
# 2011-01-04  309080800
# ...

# %%
#We can also use the Ticker class to download the historical prices and much more
# instantiate the Ticker class
aapl_data = yf.Ticker("AAPL")

# %%
# get the last month of historical prices
aapl_data.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-11-09 00:00:00-05:00  182.719278  183.877740  181.570782  182.169998
# 2023-11-10 00:00:00-05:00  183.970001  186.570007  183.529999  186.399994
# 2023-11-13 00:00:00-05:00  185.820007  186.029999  184.210007  184.800003
# 2023-11-14 00:00:00-05:00  187.699997  188.110001  186.300003  187.440002
# 2023-11-15 00:00:00-05:00  187.850006  189.500000  187.779999  188.009995
# 2023-11-16 00:00:00-05:00  189.570007  190.960007  188.649994  189.710007
# 2023-11-17 00:00:00-05:00  190.250000  190.380005  188.570007  189.690002
# 2023-11-20 00:00:00-05:00  189.889999  191.910004  189.880005  191.449997
# 2023-11-21 00:00:00-05:00  191.410004  191.520004  189.740005  190.639999
# 2023-11-22 00:00:00-05:00  191.490005  192.929993  190.830002  191.309998
# 2023-11-24 00:00:00-05:00  190.869995  190.899994  189.250000  189.970001
# 2023-11-27 00:00:00-05:00  189.919998  190.669998  188.899994  189.789993
# ...

# %%
# get stock's info
aapl_data.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
# show corporate actions
aapl_data.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2023-11-10 00:00:00-05:00       0.24           0.0

# %%
# show financials
aapl_data.financials
# Out:
#                                                         2023-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.147192
# Normalized EBITDA                                   125820000000.0
# Net Income From Continuing Operation Net Minori...   96995000000.0
# Reconciled Depreciation                              11519000000.0
# Reconciled Cost Of Revenue                          214137000000.0
# EBITDA                                              125820000000.0
# EBIT                                                114301000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    96995000000.0
# Net Income From Continuing And Discontinued Ope...   96995000000.0
# ...

# %%
# show quarterly financials
aapl_data.quarterly_financials
# Out:
#                                                        2023-09-30  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                       0.149715
# Normalized EBITDA                                   29622000000.0
# Net Income From Continuing Operation Net Minori...  22956000000.0
# Reconciled Depreciation                              2653000000.0
# Reconciled Cost Of Revenue                          49071000000.0
# EBITDA                                              29622000000.0
# EBIT                                                26969000000.0
# Net Interest Income                                           NaN
# Interest Expense                                              NaN
# Interest Income                                               NaN
# Normalized Income                                   22956000000.0
# Net Income From Continuing And Discontinued Ope...  22956000000.0
# ...

# %%
# show earnings
aapl_data.earnings
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# <ipython-input-16-2067080cb271> in <cell line: 2>()
#       1 # show earnings
# ----> 2 aapl_data.earnings
#
# /usr/local/lib/python3.10/dist-packages/yfinance/ticker.py in earnings(self)
#     156     @property
#     157     def earnings(self) -> _pd.DataFrame:
# --> 158         return self.get_earnings()
#     159
#     160     @property
#
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py in get_earnings(self, proxy, as_dict, freq)
#    1810         """
#    1811         self._fundamentals.proxy = proxy
# -> 1812         data = self._fundamentals.earnings[freq]
#    1813         if as_dict:
#    1814             dict_data = data.to_dict()
#
# /usr/local/lib/python3.10/dist-packages/yfinance/scrapers/fundamentals.py in earnings(self)
#      32     def earnings(self) -> dict:
#      33         if self._earnings is None:
# ...

# %%
# show quarterly earnings
aapl_data.quarterly_earnings
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# <ipython-input-17-06919c82f1b1> in <cell line: 2>()
#       1 # show quarterly earnings
# ----> 2 aapl_data.quarterly_earnings
#
# /usr/local/lib/python3.10/dist-packages/yfinance/ticker.py in quarterly_earnings(self)
#     160     @property
#     161     def quarterly_earnings(self) -> _pd.DataFrame:
# --> 162         return self.get_earnings(freq='quarterly')
#     163
#     164     @property
#
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py in get_earnings(self, proxy, as_dict, freq)
#    1810         """
#    1811         self._fundamentals.proxy = proxy
# -> 1812         data = self._fundamentals.earnings[freq]
#    1813         if as_dict:
#    1814             dict_data = data.to_dict()
#
# /usr/local/lib/python3.10/dist-packages/yfinance/scrapers/fundamentals.py in earnings(self)
# ...

# %%
# show upcoming events, such as earnings
aapl_data.calendar
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# <ipython-input-18-eb667600d148> in <cell line: 2>()
#       1 # show upcoming events, such as earnings
# ----> 2 aapl_data.calendar
#
# /usr/local/lib/python3.10/dist-packages/yfinance/ticker.py in calendar(self)
#     148     @property
#     149     def calendar(self) -> _pd.DataFrame:
# --> 150         return self.get_calendar()
#     151
#     152     @property
#
# /usr/local/lib/python3.10/dist-packages/yfinance/base.py in get_calendar(self, proxy, as_dict)
#    1704     def get_calendar(self, proxy=None, as_dict=False):
#    1705         self._quote.proxy = proxy
# -> 1706         data = self._quote.calendar
#    1707         if as_dict:
#    1708             return data.to_dict()
#
# /usr/local/lib/python3.10/dist-packages/yfinance/scrapers/quote.py in calendar(self)
#     590     def calendar(self) -> pd.DataFrame:
# ...

# %%
pip install nasdaq-data-link

# %%
#1.2 Getting data from Nasdaq Data Link
import pandas as pd
import nasdaqdatalink

# %%
nasdaqdatalink.ApiConfig.api_key = "rXzvSxgtpECTSF4c9vEA"

# %%
df = nasdaqdatalink.get(dataset="WIKI/AAPL",
start_date="2011-01-01",
end_date="2023-12-08")

# %%
print(f"Downloaded {len(df)} rows of data.")
df.head()
# Out:
# Downloaded 1818 rows of data.
#                 Open    High       Low   Close      Volume  Ex-Dividend  \
# Date
# 2011-01-03  325.6400  330.26  324.8365  329.57  15897800.0          0.0
# 2011-01-04  332.4400  332.50  328.1500  331.29  11038600.0          0.0
# 2011-01-05  329.5500  334.34  329.5000  334.00   9125700.0          0.0
# 2011-01-06  334.7194  335.25  332.9000  333.73  10729600.0          0.0
# 2011-01-07  333.9900  336.35  331.9000  336.12  11140400.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2011-01-03          1.0  41.849279  42.443013  41.746018   42.354338
# 2011-01-04          1.0  42.723173  42.730884  42.171849   42.575382
# 2011-01-05          1.0  42.351768  42.967350  42.345342   42.923655
# 2011-01-06          1.0  43.016108  43.084298  42.782290   42.888956
# 2011-01-07          1.0  42.922370  43.225663  42.653776   43.196105
#
#             Adj. Volume
# Date
# 2011-01-03  111284600.0
# ...

# %%
print(f"Downloaded {len(df)} rows of data.")
df.tail()
# Out:
# Downloaded 1818 rows of data.
#               Open    High     Low    Close      Volume  Ex-Dividend  \
# Date
# 2018-03-21  175.04  175.09  171.26  171.270  35247358.0          0.0
# 2018-03-22  170.00  172.68  168.60  168.845  41051076.0          0.0
# 2018-03-23  168.39  169.92  164.94  164.940  40248954.0          0.0
# 2018-03-26  168.07  173.10  166.44  172.770  36272617.0          0.0
# 2018-03-27  173.68  175.15  166.92  168.340  38962839.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
# 2018-03-21          1.0     175.04     175.09    171.26     171.270
# 2018-03-22          1.0     170.00     172.68    168.60     168.845
# 2018-03-23          1.0     168.39     169.92    164.94     164.940
# 2018-03-26          1.0     168.07     173.10    166.44     172.770
# 2018-03-27          1.0     173.68     175.15    166.92     168.340
#
#             Adj. Volume
# Date
# 2018-03-21   35247358.0
# 2018-03-22   41051076.0
# ...

# %%
#Download multiple stocks
COLUMNS = ["ticker", "date", "adj_close"]
df = nasdaqdatalink.get_table("WIKI/PRICES",
ticker=["AAPL", "MSFT", "INTC"],
qopts={"columns": COLUMNS},
date={"gte": "2011-01-01",
"lte": "2023-10-31"},
paginate=True)
df.head()
df.tail()
# Out:
#      ticker       date  adj_close
# None
# 5450   AAPL 2011-01-07  43.196105
# 5451   AAPL 2011-01-06  42.888956
# 5452   AAPL 2011-01-05  42.923655
# 5453   AAPL 2011-01-04  42.575382
# 5454   AAPL 2011-01-03  42.354338

# %%
#Pivot the data from long to wide
# set the date as index
df = df.set_index("date")

# use the pivot function to reshape the data
df_wide = df.pivot(columns="ticker")
df_wide.head()
# Out:
#             adj_close
# ticker           AAPL       INTC       MSFT
# date
# 2011-01-03  42.354338  16.488706  23.211568
# 2011-01-04  42.575382  16.725954  23.300747
# 2011-01-05  42.923655  16.559880  23.228159
# 2011-01-06  42.888956  16.425440  23.908412
# 2011-01-07  43.196105  16.338449  23.725905

# %%
df = df.set_index("date")
df_wide = df.pivot(columns="ticker")
df_wide.head()
df_wide.tail()
# Out:
#            adj_close
# ticker          AAPL   INTC   MSFT
# date
# 2018-03-21   171.270  51.56  92.48
# 2018-03-22   168.845  50.83  89.79
# 2018-03-23   164.940  49.36  87.18
# 2018-03-26   172.770  52.48  93.78
# 2018-03-27   168.340  51.19  89.47

# %%
#1.3 Getting data from Alpha Vantage

# %%
pip install alpha_vantage

# %%
pip install alpha_vantage pandas

# %%
#1.Import the libraries
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
#2.Authenticate using the personal API key and select the API
ALPHA_VANTAGE_API_KEY = "Y0OYFSO6IJG7BYQP6"
crypto_api = CryptoCurrencies(key=ALPHA_VANTAGE_API_KEY,
output_format= "pandas")

# %%
#3.Download the daily prices of Bitcoin, expressed in EUR
data, meta_data = crypto_api.get_digital_currency_daily(
symbol="BTC",
market="EUR"
)

# %%
meta_data
# Out:
# {'1. Information': 'Daily Prices and Volumes for Digital Currency',
#  '2. Digital Currency Code': 'BTC',
#  '3. Digital Currency Name': 'Bitcoin',
#  '4. Market Code': 'EUR',
#  '5. Market Name': 'Euro',
#  '6. Last Refreshed': '2023-12-10 00:00:00',
#  '7. Time Zone': 'UTC'}

# %%
#4.Download the realtime exchange rate
crypto_api.get_digital_currency_exchange_rate(
from_currency="BTC",
to_currency="USD"
)[0].transpose()
# Out:
#                       Realtime Currency Exchange Rate
# 1. From_Currency Code                             BTC
# 2. From_Currency Name                         Bitcoin
# 3. To_Currency Code                               USD
# 4. To_Currency Name              United States Dollar
# 5. Exchange Rate                       43751.03000000
# 6. Last Refreshed                 2023-12-10 08:54:03
# 7. Time Zone                                      UTC
# 8. Bid Price                           43751.02000000
# 9. Ask Price                           43751.03000000

# %%
#Import the libraries
import requests
import pandas as pd
from io import BytesIO

# %%
#Download Bitcoin's intraday data
AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
    "function": "CRYPTO_INTRADAY",
    "symbol": "ETH",
    "market": "USD",
    "interval": "30min",
    "outputsize": "full",
    "apikey": ALPHA_VANTAGE_API_KEY
}
r = requests.get(AV_API_URL, params=parameters)
data = r.json()
# Check if the request was successful
if "Time Series Crypto (30min)" in data:
    # Convert data to a DataFrame
    df = pd.DataFrame(data["Time Series Crypto (30min)"]).transpose()
    print(df.head())
else:
    print("Error in API response:", data)

df
# Out:
# Error in API response: {'Information': 'Thank you for using Alpha Vantage! This is a premium endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium endpoints'}
#            ticker  adj_close
# date
# 2018-03-27   MSFT  89.470000
# 2018-03-26   MSFT  93.780000
# 2018-03-23   MSFT  87.180000
# 2018-03-22   MSFT  89.790000
# 2018-03-21   MSFT  92.480000
# ...           ...        ...
# 2011-01-07   AAPL  43.196105
# 2011-01-06   AAPL  42.888956
# 2011-01-05   AAPL  42.923655
# 2011-01-04   AAPL  42.575382
# 2011-01-03   AAPL  42.354338
#
# [5455 rows x 2 columns]

# %%
#Download the upcoming earnings announcements
AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
"function": "EARNINGS_CALENDAR",
"horizon": "3month",
"apikey": ALPHA_VANTAGE_API_KEY
}
r = requests.get(AV_API_URL, params=parameters)
pd.read_csv(BytesIO(r.content))
# Out:
#      symbol                             name  reportDate fiscalDateEnding  \
# 0         A         Agilent Technologies Inc  2024-02-26       2024-01-31
# 1        AA                       Alcoa Corp  2024-01-16       2023-12-31
# 2     AABVF                            AABVF  2023-12-14       2023-10-31
# 3     AACTF                            AACTF  2024-02-28       2023-12-31
# 4     AAGIY                            AAGIY  2024-03-08       2023-12-31
# ...     ...                              ...         ...              ...
# 5908   ZVIA              Zevia PBC - Class A  2024-02-28       2023-12-31
# 5909   ZVOI                             ZVOI  2024-02-28       2023-12-31
# 5910   ZVRA           Zevra Therapeutics Inc  2024-03-05       2023-12-31
# 5911    ZWS  Zurn Elkay Water Solutions Corp  2024-02-05       2023-12-31
# 5912   ZYXI                        Zynex Inc  2024-03-04       2023-12-31
#
#       estimate currency
# 0         1.22      USD
# 1        -0.70      USD
# ...

# %%
#Download the upcoming earnings announcements:
AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
"function": "EARNINGS_CALENDAR",
"horizon": "3month",
"apikey": ALPHA_VANTAGE_API_KEY
}
r = requests.get(AV_API_URL, params=parameters)
pd.read_csv(BytesIO(r.content))
# Out:
#      symbol                             name  reportDate fiscalDateEnding  \
# 0         A         Agilent Technologies Inc  2024-02-26       2024-01-31
# 1        AA                       Alcoa Corp  2024-01-16       2023-12-31
# 2     AABVF                            AABVF  2023-12-14       2023-10-31
# 3     AACTF                            AACTF  2024-02-28       2023-12-31
# 4     AAGIY                            AAGIY  2024-03-08       2023-12-31
# ...     ...                              ...         ...              ...
# 5908   ZVIA              Zevia PBC - Class A  2024-02-28       2023-12-31
# 5909   ZVOI                             ZVOI  2024-02-28       2023-12-31
# 5910   ZVRA           Zevra Therapeutics Inc  2024-03-05       2023-12-31
# 5911    ZWS  Zurn Elkay Water Solutions Corp  2024-02-05       2023-12-31
# 5912   ZYXI                        Zynex Inc  2024-03-04       2023-12-31
#
#       estimate currency
# 0         1.22      USD
# 1        -0.70      USD
# ...

# %%
#Bonus
#Get Tesla's earnings
AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
    "function": "EARNINGS",
    "symbol": "TSLA",
    "apikey": ALPHA_VANTAGE_API_KEY
}
r = requests.get(AV_API_URL,  params=parameters)
data = r.json()

# %%
data.keys()
# Out:
# dict_keys(['symbol', 'annualEarnings', 'quarterlyEarnings'])

# %%
df = pd.DataFrame(data["quarterlyEarnings"])
df.head()
# Out:
#   fiscalDateEnding reportedDate reportedEPS estimatedEPS surprise  \
# 0       2023-09-30   2023-10-18        0.66         0.72    -0.06
# 1       2023-06-30   2023-07-19        0.91         0.82     0.09
# 2       2023-03-31   2023-04-19        0.85         0.85        0
# 3       2022-12-31   2023-01-25        1.19         1.13     0.06
# 4       2022-09-30   2022-10-19        1.05         0.99     0.06
#
#   surprisePercentage
# 0            -8.3333
# 1            10.9756
# 2                  0
# 3             5.3097
# 4             6.0606

# %%
#Download the upcoming IPOs
import csv

AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
    "function": "IPO_CALENDAR",
    "apikey": ALPHA_VANTAGE_API_KEY
}

with requests.Session() as s:
    download = s.get(AV_API_URL, params=parameters)
    decoded_content = download.content.decode("utf-8")
    ipos_list = list(csv.reader(decoded_content.splitlines(), delimiter=","))

df = pd.DataFrame(ipos_list[1:], columns=ipos_list[0])
df
# Out:
# Empty DataFrame
# Columns: [symbol, name, ipoDate, priceRangeLow, priceRangeHigh, currency, exchange]
# Index: []

# %%
#Download Google's stock prices using the TimeSeries module
from alpha_vantage.timeseries import TimeSeries

ts = TimeSeries(key=ALPHA_VANTAGE_API_KEY, output_format="pandas")
data, _ = ts.get_daily("GOOGL", outputsize="full")
print(f"Downloaded {len(data)} observations")
data
# Out:
# Downloaded 4861 observations
#             1. open  2. high   3. low  4. close   5. volume
# date
# 2023-12-08   134.20   136.40  134.025   134.990  32260112.0
# 2023-12-07   135.04   138.56  134.700   136.930  56767100.0
# 2023-12-06   131.44   131.84  129.875   130.020  22897543.0
# 2023-12-05   128.95   132.14  128.250   130.990  27384784.0
# 2023-12-04   129.88   130.03  127.900   129.270  36669876.0
# ...             ...      ...      ...       ...         ...
# 2004-08-25   104.76   108.00  103.880   106.000   9188600.0
# 2004-08-24   111.24   111.60  103.570   104.870  15247300.0
# 2004-08-23   110.76   113.48  109.050   109.400  18256100.0
# 2004-08-20   101.01   109.08  100.500   108.310  22834300.0
# 2004-08-19   100.01   104.06   95.960   100.335  44659000.0
#
# [4861 rows x 5 columns]

# %%
#Similarly, we can download the intraday prices
data, _ = ts.get_intraday("GOOGL", interval="5min", outputsize="full")
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2023-12-08 19:55:00   134.73   134.77  134.70    134.75     3540.0
# 2023-12-08 19:50:00   134.78   134.78  134.73    134.73     1813.0
# 2023-12-08 19:45:00   134.73   134.78  134.73    134.78     1232.0
# 2023-12-08 19:40:00   134.79   134.79  134.71    134.75      177.0
# 2023-12-08 19:35:00   134.75   134.78  134.71    134.78      461.0
# ...                      ...      ...     ...       ...        ...
# 2023-11-17 04:20:00   135.93   135.96  135.61    135.68     4938.0
# 2023-11-17 04:15:00   136.13   136.13  135.93    135.93     2224.0
# 2023-11-17 04:10:00   136.01   136.13  136.00    136.13      477.0
# 2023-11-17 04:05:00   136.23   136.24  136.00    136.01     4128.0
# 2023-11-17 04:00:00   136.46   136.58  136.13    136.18     4228.0
#
# [2843 rows x 5 columns]

# %%
#1.4 Getting data from CoinGecko

# %%
pip install pycoingecko

# %%
pip install CoinGeckoAPI
# Out:
# ERROR: Could not find a version that satisfies the requirement CoinGeckoAPI (from versions: none)
# ERROR: No matching distribution found for CoinGeckoAPI

# %%
#Import the libraries
from pycoingecko import CoinGeckoAPI
from datetime import datetime
import pandas as pd

# %%
#Instantiate the CoinGecko API
cg = CoinGeckoAPI()

# %%
#Get Bitcoin's OHLC prices from the last 14 days
ohlc = cg.get_coin_ohlc_by_id(
id="bitcoin", vs_currency="usd", days="14"
)
ohlc_df = pd.DataFrame(ohlc)
ohlc_df.columns = ["date", "open", "high", "low", "close"]
ohlc_df["date"] = pd.to_datetime(ohlc_df["date"], unit="ms")
ohlc_df
# Out:
#                   date     open     high      low    close
# 0  2023-11-26 12:00:00  37778.0  37778.0  37728.0  37728.0
# 1  2023-11-26 16:00:00  37687.0  37687.0  37390.0  37390.0
# 2  2023-11-26 20:00:00  37420.0  37420.0  37184.0  37230.0
# 3  2023-11-27 00:00:00  37321.0  37652.0  37321.0  37647.0
# 4  2023-11-27 04:00:00  37479.0  37515.0  37330.0  37330.0
# ..                 ...      ...      ...      ...      ...
# 80 2023-12-09 20:00:00  44118.0  44118.0  43944.0  43966.0
# 81 2023-12-10 00:00:00  43946.0  44006.0  43909.0  43909.0
# 82 2023-12-10 04:00:00  43715.0  43802.0  43715.0  43797.0
# 83 2023-12-10 08:00:00  43845.0  43939.0  43845.0  43918.0
# 84 2023-12-10 12:00:00  43968.0  43968.0  43788.0  43788.0
#
# [85 rows x 5 columns]

# %%
#Get the top 7 trending coins (based on the # of searches in the last 24h) from CoinGecko
trending_coins = cg.get_search_trending()
(
pd.DataFrame([coin["item"] for coin in trending_coins["coins"]])
.drop(columns=["thumb", "small", "large"])
)
# Out:
#                        id  coin_id             name  symbol  market_cap_rank  \
# 0                edu-coin    29948      Open Campus     EDU              249
# 1         chihuahua-token    22485  Chihuahua Chain  HUAHUA              677
# 2   jito-governance-token    33228             Jito     JTO              147
# 3                    bonk    28600             Bonk    BONK              101
# 4                celestia    31967         Celestia     TIA               55
# 5                  beam-2    32417             Beam    BEAM               80
# 6               decimated     8271        Decimated     DIO              853
# 7                  solana     4128           Solana     SOL                6
# 8                ethereum      279         Ethereum     ETH                2
# 9            seedify-fund    14614     Seedify.fund   SFUND              199
# 10            immutable-x    17233        Immutable     IMX               34
# ...

# %%
#Get Bitcoin's current price in USD

cg.get_price(ids="bitcoin", vs_currencies="usd")
# Out:
# {'bitcoin': {'usd': 43827}}

# %%
#Get current price of ETH and BTC in USD and EUR
cg.get_price(ids=["bitcoin", "ethereum"], vs_currencies=["usd", "eur"])
# Out:
# {'bitcoin': {'usd': 43831, 'eur': 40684},
#  'ethereum': {'usd': 2345.38, 'eur': 2176.98}}

# %%
#Get the current BTC/USD eschange rate, market capitalization, 24h volumne and change and the last-updated timestamp
cg.get_price(ids="bitcoin", vs_currencies="usd",
             include_market_cap=True,
             include_24hr_vol=True,
             include_24hr_change=True,
             include_last_updated_at=True)
# Out:
# {'bitcoin': {'usd': 43831,
#   'usd_market_cap': 856759041002.5604,
#   'usd_24h_vol': 14570827875.99835,
#   'usd_24h_change': 0.020345321655416644,
#   'last_updated_at': 1702199322}}

# %%
#Get the list of all supported coin ids, together with their name and symbol
pd.DataFrame(cg.get_coins_list())
# Out:
#                         id symbol                 name
# 0                   01coin    zoc               01coin
# 1                   0chain    zcn                  Zus
# 2      0-knowledge-network    0kn  0 Knowledge Network
# 3                    0-mee    ome                O-MEE
# 4            0vix-protocol    vix        0VIX Protocol
# ...                    ...    ...                  ...
# 11378             zynecoin    zyn             Zynecoin
# 11379              zynergy    zyn              Zynergy
# 11380                zyrri    zyr                Zyrri
# 11381                  zyx    zyx                  ZYX
# 11382                  zzz    zzz          GoSleep ZZZ
#
# [11383 rows x 3 columns]

# %%
#Get all the coins market data
pd.DataFrame(cg.get_coins_markets(vs_currency="eur"))
# Out:
#                    id symbol         name  \
# 0             bitcoin    btc      Bitcoin
# 1            ethereum    eth     Ethereum
# 2              tether   usdt       Tether
# 3         binancecoin    bnb          BNB
# 4              ripple    xrp          XRP
# ..                ...    ...          ...
# 95  pancakeswap-token   cake  PancakeSwap
# 96               frax   frax         Frax
# 97               pepe   pepe         Pepe
# 98    curve-dao-token    crv    Curve DAO
# 99    gatechain-token     gt         Gate
#
#                                                 image  current_price  \
# 0   https://assets.coingecko.com/coins/images/1/la...   40680.000000
# 1   https://assets.coingecko.com/coins/images/279/...    2176.810000
# 2   https://assets.coingecko.com/coins/images/325/...       0.928539
# 3   https://assets.coingecko.com/coins/images/825/...     222.850000
# 4   https://assets.coingecko.com/coins/images/44/l...       0.614617
# ...

# %%
#Get all the supported crypto exchanges:
exchanges_df = pd.DataFrame(cg.get_exchanges_list(per_page=250))
print(exchanges_df)

exchanges_df.head()
# Out:
#                         id                    name  year_established  \
# 0                     okex                     OKX            2017.0
# 1               bybit_spot                   Bybit            2018.0
# 2                     gdax       Coinbase Exchange            2012.0
# 3                     gate                 Gate.io               NaN
# 4                   kucoin                  KuCoin            2014.0
# ..                     ...                     ...               ...
# 245  pancakeswap-v2-zksync    PancakeSwap (zkSync)               NaN
# 246   pancakeswap-v3-opbnb  Pancakeswap V3 (opBnb)               NaN
# 247                  xswap                   XSwap               NaN
# 248                 tethys          Tethys Finance            2021.0
# 249                ubeswap                 Ubeswap               NaN
#
#                     country  \
# 0                Seychelles
# 1    British Virgin Islands
# 2             United States
# ...

# %%
exchanges_df.tail()
# Out:
#                         id                    name  year_established  \
# 245  pancakeswap-v2-zksync    PancakeSwap (zkSync)               NaN
# 246   pancakeswap-v3-opbnb  Pancakeswap V3 (opBnb)               NaN
# 247                  xswap                   XSwap               NaN
# 248                 tethys          Tethys Finance            2021.0
# 249                ubeswap                 Ubeswap               NaN
#
#                   country description  \
# 245                  None
# 246                  None
# 247                  None
# 248  United Arab Emirates
# 249                  None
#
#                                            url  \
# 245  https://pancakeswap.finance/?chain=zkSync
# 246           https://pancakeswap.finance/swap
# 247           https://app.xspswap.finance/swap
# 248                    https://tethys.finance/
# 249             https://app.ubeswap.org/#/swap
#
#                                                  image has_trading_incentive  \
# ...

# %%
#Get a summary of DEFI

# %%
cg.get_global_decentralized_finance_defi()
# Out:
# {'defi_market_cap': '71857666091.3650809067495078113',
#  'eth_market_cap': '281905592250.7925151903552102391',
#  'defi_to_eth_ratio': '25.4899753912785562982232113967189267878744056966635547498024326',
#  'trading_volume_24h': '4270582132.808491654005551084695',
#  'defi_dominance': '4.1988963352870546262085743344031873737875886831349374195505446',
#  'top_coin_name': 'Lido Staked Ether',
#  'top_coin_defi_dominance': 30.062097927848047}
