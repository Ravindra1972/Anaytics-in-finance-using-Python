# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravindra1972/Anaytics-in-finance-using-Python/blob/main/Simple_Returns_and_Logarithmic_Returns_Visualization_Yahoo_Py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Simpler Returns - Part I

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Download the data for Microsoft (‘MSFT’) from Yahoo Finance for the period ‘2000-1-1’ until today.

# %%
import numpy as np
import yfinance as yf
import datetime as dt

# %%
start = dt.datetime(2010,1,1)
end =dt.datetime(2023,12,1)
symbol = 'MSFT'
source = 'yahoo'
ticker = 'MSFT'

MSFT = yf.download(ticker, start, end)
MSFT
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04   30.620001   31.100000   30.590000   30.950001   23.474920
# 2010-01-05   30.850000   31.100000   30.639999   30.959999   23.482502
# 2010-01-06   30.879999   31.080000   30.520000   30.770000   23.338388
# 2010-01-07   30.629999   30.700001   30.190001   30.450001   23.095678
# 2010-01-08   30.280001   30.879999   30.240000   30.660000   23.254965
# ...                ...         ...         ...         ...         ...
# 2023-11-24  377.329987  377.970001  375.140015  377.429993  377.429993
# 2023-11-27  376.779999  380.640015  376.200012  378.609985  378.609985
# 2023-11-28  378.350006  383.000000  378.160004  382.700012  382.700012
# 2023-11-29  383.760010  384.299988  377.440002  378.850006  378.850006
# 2023-11-30  378.489990  380.089996  375.470001  378.910004  378.910004
#
#               Volume
# Date
# 2010-01-04  38409100
# 2010-01-05  49749600
# 2010-01-06  58182400
# 2010-01-07  50559700
# 2010-01-08  51197400
# ...              ...
# 2023-11-24  10176600
# 2023-11-27  22179200
# 2023-11-28  20453100
# 2023-11-29  28963400
# 2023-11-30  30554400
#
# [3502 rows x 6 columns]

# %% [markdown]
# Apply the .**head()** and **.tail()** methods to check if the data is ok. Always pay attention to the dates. Try to get an idea about how the stock price changed during the period.

# %%
MSFT.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2010-01-04  30.620001  31.100000  30.590000  30.950001  23.474920  38409100
# 2010-01-05  30.850000  31.100000  30.639999  30.959999  23.482502  49749600
# 2010-01-06  30.879999  31.080000  30.520000  30.770000  23.338388  58182400
# 2010-01-07  30.629999  30.700001  30.190001  30.450001  23.095678  50559700
# 2010-01-08  30.280001  30.879999  30.240000  30.660000  23.254965  51197400

# %%
MSFT.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-11-24  377.329987  377.970001  375.140015  377.429993  377.429993
# 2023-11-27  376.779999  380.640015  376.200012  378.609985  378.609985
# 2023-11-28  378.350006  383.000000  378.160004  382.700012  382.700012
# 2023-11-29  383.760010  384.299988  377.440002  378.850006  378.850006
# 2023-11-30  378.489990  380.089996  375.470001  378.910004  378.910004
#
#               Volume
# Date
# 2023-11-24  10176600
# 2023-11-27  22179200
# 2023-11-28  20453100
# 2023-11-29  28963400
# 2023-11-30  30554400

# %% [markdown]
# ### Simple Rate of Return

# %% [markdown]
# Calculate the simple returns of ‘MSFT’ for the given timeframe.

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
MSFT['simple_return'] = (MSFT['Adj Close'] / MSFT['Adj Close'].shift(1)) - 1
print (MSFT['simple_return'])
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.000323
# 2010-01-06   -0.006137
# 2010-01-07   -0.010400
# 2010-01-08    0.006897
#                 ...
# 2023-11-24   -0.001112
# 2023-11-27    0.003126
# 2023-11-28    0.010803
# 2023-11-29   -0.010060
# 2023-11-30    0.000158
# Name: simple_return, Length: 3502, dtype: float64

# %%
#Plot the simple returns on a graph.
import matplotlib.pyplot as plt

# %%
MSFT['simple_return'].plot(figsize=(8, 5))
plt.show()

# %%
#Calculate the average daily return.
avg_returns_d = MSFT['simple_return'].mean()
avg_returns_d
#Estimate the average annual return.
avg_returns_a = MSFT['simple_return'].mean() * 250
avg_returns_a
print (str(round(avg_returns_a, 4) * 100) + ' %')
# Out:
# 23.22 %

# %%
# Logarithmic Returns
import numpy as np
import yfinance as yf
import datetime as dt
start = dt.datetime(2010,1,1)
end =dt.datetime(2023,12,1)
symbol = 'MSFT'
source = 'yahoo'
ticker = 'MSFT'

MSFT = yf.download(ticker, start, end)
MSFT
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04   30.620001   31.100000   30.590000   30.950001   23.474920
# 2010-01-05   30.850000   31.100000   30.639999   30.959999   23.482502
# 2010-01-06   30.879999   31.080000   30.520000   30.770000   23.338388
# 2010-01-07   30.629999   30.700001   30.190001   30.450001   23.095678
# 2010-01-08   30.280001   30.879999   30.240000   30.660000   23.254965
# ...                ...         ...         ...         ...         ...
# 2023-11-24  377.329987  377.970001  375.140015  377.429993  377.429993
# 2023-11-27  376.779999  380.640015  376.200012  378.609985  378.609985
# 2023-11-28  378.350006  383.000000  378.160004  382.700012  382.700012
# 2023-11-29  383.760010  384.299988  377.440002  378.850006  378.850006
# 2023-11-30  378.489990  380.089996  375.470001  378.910004  378.910004
#
#               Volume
# Date
# 2010-01-04  38409100
# 2010-01-05  49749600
# 2010-01-06  58182400
# 2010-01-07  50559700
# 2010-01-08  51197400
# ...              ...
# 2023-11-24  10176600
# 2023-11-27  22179200
# 2023-11-28  20453100
# 2023-11-29  28963400
# 2023-11-30  30554400
#
# [3502 rows x 6 columns]

# %%
MSFT.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2010-01-04  30.620001  31.100000  30.590000  30.950001  23.474920  38409100
# 2010-01-05  30.850000  31.100000  30.639999  30.959999  23.482502  49749600
# 2010-01-06  30.879999  31.080000  30.520000  30.770000  23.338388  58182400
# 2010-01-07  30.629999  30.700001  30.190001  30.450001  23.095678  50559700
# 2010-01-08  30.280001  30.879999  30.240000  30.660000  23.254965  51197400

# %%
#Log Returns
# ln(Pt/Pt−1)

# %%
#Calculate the Log returns for Microsoft.
MSFT['log_return'] = np.log(MSFT['Adj Close'] / MSFT['Adj Close'].shift(1))
print (MSFT['log_return'])
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.000323
# 2010-01-06   -0.006156
# 2010-01-07   -0.010454
# 2010-01-08    0.006873
#                 ...
# 2023-11-24   -0.001112
# 2023-11-27    0.003122
# 2023-11-28    0.010745
# 2023-11-29   -0.010111
# 2023-11-30    0.000158
# Name: log_return, Length: 3502, dtype: float64

# %%
#Plot the results on a graph.
#Plot the log returns on a graph.
import matplotlib.pyplot as plt
MSFT['log_return'].plot(figsize=(8, 5))
plt.show()

# %%
#Estimate the daily and the annual mean of the obtained log returns.
log_return_d = MSFT['log_return'].mean()
log_return_d
# Out:
# 0.00079444904047392

# %%
log_return_a = MSFT['log_return'].mean() * 250
log_return_a
# Out:
# 0.19861226011848002

# %%
#Print the result in a presentable form.
print (str(round(log_return_a, 5) * 100) + ' %')
# Out:
# 19.861 %
